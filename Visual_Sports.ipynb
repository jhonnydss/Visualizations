# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Data_Sports.xlsx')

# %%
df.head()
# Out:
#         Sport  2017  2013  2008  2007  2006  2005  2004
# 0    Football    37    39    41    43    43    34    37
# 1  Basketball    11    12     9    11    12    12    13
# 2    Baseball     9    14    10    13    11    12    10
# 3      Soccer     7     4     3     2     2     3     2
# 4  Ice hockey     4     3     4     4     2     4     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sport   22 non-null     object
#  1   2017    22 non-null     int64
#  2   2013    22 non-null     int64
#  3   2008    22 non-null     int64
#  4   2007    22 non-null     int64
#  5   2006    22 non-null     int64
#  6   2005    22 non-null     int64
#  7   2004    22 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.5+ KB

# %%
df.nunique()
# Out:
# Sport    22
# 2017     10
# 2013      9
# 2008     10
# 2007      9
# 2006      8
# 2005      9
# 2004     10
# dtype: int64

# %%
sns.displot(df[2017], kde = False)

# %%
anios = df.groupby([2017])['Sport'].nunique()

# %%
sns.set()  # use Seaborn styles

df.pivot_table( columns='Sport', aggfunc='mean').plot()
plt.ylabel('Porcentaje de preferencia')
plt.xlabel('Anios')
plt.legend(loc=(1.02,0))
plt.figure(figsize=(20,20))

# %%
# this is a pandas Series
anios
# Out:
# 2017
# 0     7
# 1     6
# 2     2
# 4     1
# 5     1
# 7     1
# 9     1
# 11    1
# 15    1
# 37    1
# Name: Sport, dtype: int64

# %%
plt.style.use('seaborn')
plt.plot(anios, c= 'k')

# %%
sns.boxplot(data = df.loc[:,[2017,2008]])
# Out:
# <AxesSubplot:>
